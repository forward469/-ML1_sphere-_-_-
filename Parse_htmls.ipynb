# %%
# !brew install pymorphy
# Out:
# Updating Homebrew...
# ^C

# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup
import urllib

import os
from functools import reduce

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-4c7a3c4d24e3> in <module>
#       9 from functools import reduce
#      10
# ---> 11 import nltk
#      12 nltk.download('punkt')
#      13 nltk.download('averaged_perceptron_tagger')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
CONTENT_DIR_PATH = '/Users/pus/ТЕХНОСФЕРА/Data Mining/project/anomaly-detection-competition-ml1-ts-fall-2019/content/content'
for filename in os.listdir(CONTENT_DIR_PATH):
    print(filename)
# Out:
# 12479.dat
# 7651.dat
# 15316.dat
# 8562.dat
# 14008.dat
# 7889.dat
# 13767.dat
# 1220.dat
# 2729.dat
# 17501.dat
# 5046.dat
# 18632.dat
# 26904.dat
# 4358.dat
# 3437.dat
# 11170.dat
# 3351.dat
# 11616.dat
# 16179.dat
# 17267.dat
# 5720.dat
# 18154.dat
# 10508.dat
# 13001.dat
# 1546.dat
# 6229.dat
# 24875.dat
# 7137.dat
# 15470.dat
# 8204.dat
# 13015.dat
# 1552.dat
# 7123.dat
# 24861.dat
# 8210.dat
# 15464.dat
# 3345.dat
# 11602.dat
# 17273.dat
# 18140.dat
# 5734.dat
# 21919.dat
# 17515.dat
# 26910.dat
# 18626.dat
# 5052.dat
# 19538.dat
# 3423.dat
# 11164.dat
# 23868.dat
# 7645.dat
# 8576.dat
# 15302.dat
# 978.dat
# 9668.dat
# 13773.dat
# 1234.dat
# 10252.dat
# 2715.dat
# 26938.dat
# 20391.dat
# 19510.dat
# 4364.dat
# 16623.dat
# 9898.dat
# 23840.dat
# 12445.dat
# 22586.dat
# 950.dat
# 13983.dat
# 9640.dat
# 14034.dat
# 23698.dat
# 6573.dat
# 788.dat
# 24691.dat
# 9126.dat
# 14752.dat
# 6215.dat
# 8238.dat
# 24849.dat
# 12323.dat
# 26086.dat
# 19276.dat
# 4402.dat
# 16145.dat
# ...

# %%
with open(CONTENT_DIR_PATH+'/12479.dat') as f:
    print(f.readlines())
# Out:
# ['school52-kirov.ru/public/mobilnye_prilozhenija_fokus.htm\n', '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">\n', '<html http-equiv="Content-Type" content="text/html; charset=UTF-8">\n', '<html><body>\n', '<p>xmlns="http://www.w3.org/1999/xhtml"&gt;\n', '</p>\n', '<title>Мобильные приложения фокус</title>\n', '<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n', '<link type="text/css" rel="StyleSheet" href="/_st/my.css">\n', '<script type="text/javascript">var homeurl="/";var urlid="page-entry";var modid="mod-publ";</script><link type="text/css" rel="StyleSheet" href="/src/base.css">\n', '<link type="text/css" rel="StyleSheet" href="/src/layer1.css">\n', '<script type="text/javascript" src="/src/jquery-1.7.2.js"></script><script type="text/javascript">window.ulb = {closeBtn: \'&#1047;&#1072;&#1082;&#1088;&#1099;&#1090;&#1100;\', error: \'&#1047;&#1072;&#1087;&#1088;&#1086;&#1096;&#1077;&#1085;&#1085;&#109
# ...

# %%
with open(CONTENT_DIR_PATH+'/12.dat') as f:
    html_1 = f.readlines()

# %%
html_1 = reduce(lambda x,y: x+y, html_1)

# %%
soup = BeautifulSoup(html_1, 'html.parser')

# %%
soup
# Out:
# bookslist.me/read2.php?id=22729
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
# <title>Прозрачные воды южных морей - 2</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Страница чтения фанфика/книги Прозрачные воды южных морей - 2" name="description"/>
# <meta content="http://bookslist.me/images/logo-withbg.png" property="og:image">
# <link href="/images/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/images/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="/images/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <link href="/read2.v2.css" rel="stylesheet" type="text/css"/>
# <script src="http://yandex.st/jquery/1.7.1/jquery.min.js" type="text/javascript"></script>
# ...

# %%
soup.find_all('meta')
# Out:
# [<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>,
#  <meta content="Страница чтения фанфика/книги Прозрачные воды южных морей - 2" name="description"/>,
#  <meta content="http://bookslist.me/images/logo-withbg.png" property="og:image">
#  <link href="/images/favicon.ico" rel="shortcut icon" type="image/ico"/>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  <link href="/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#  <link href="/images/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#  <link href="/read2.v2.css" rel="stylesheet" type="text/css"/>
#  <script src="http://yandex.st/jquery/1.7.1/jquery.min.js" type="text/javascript"></script>
#  <script src="http://yandex.st/jquery/form/2.83/jquery.form.min.js" type="text/javascript"></script>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <script src="/jquery_php/read.v1.js" type="text/javascript"></script>
#  </meta>,
# ...
